# %% [markdown]
# # PEEK with YOLOv5
#
# ## Run Inference and Save Feature Maps
#
# (Note: for large datasets, this will create tens of GB of data. Please ensure you have sufficient hard drive space.)

# %%
from peek.extractors.yolov5 import extract_yolov5_latents

extract_yolov5_latents(
    weights_path="weights/yolov5-satellite-components-det-baseline.pt",
    images_glob="image_samples/GSFC_satellite/*",
    out_dir="feature_maps/GSFC_satellite",
    imgsz=640,
    modules=None,
)

from peek import plot_PEEK

plot_PEEK(
    modules=[1, 7, 16, 19, 22],
    image_dir="image_samples/GSFC_satellite",
    feature_folder="feature_maps/GSFC_satellite",
    save_path="figures/GSFC_satellite",
    run_path="auto",
    weights_path="weights/yolov5-satellite-components-det-baseline.pt",
    verbose=True,
)
# Out:
# YOLOv5 🚀 2026-1-31 Python-3.10.19 torch-2.7.1+cu118 CUDA:0 (NVIDIA GeForce RTX 3080 Ti, 12043MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7020913 parameters, 0 gradients, 15.8 GFLOPs
# YOLOv5 🚀 2026-1-31 Python-3.10.19 torch-2.7.1+cu118 CUDA:0 (NVIDIA GeForce RTX 3080 Ti, 12043MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7020913 parameters, 0 gradients, 15.8 GFLOPs
# [plotting] saved prediction: /home/rwhite/NFS/All_Team/Ryan/PEEK/runs/peek_detect/GSFC_satellite/frame00000.png
# [plotting] saved prediction: /home/rwhite/NFS/All_Team/Ryan/PEEK/runs/peek_detect/GSFC_satellite/frame00062.png
# [plotting] saved prediction: /home/rwhite/NFS/All_Team/Ryan/PEEK/runs/peek_detect/GSFC_satellite/frame00099.png
# [plotting] saved prediction: /home/rwhite/NFS/All_Team/Ryan/PEEK/runs/peek_detect/GSFC_satellite/frame00177.png
# [plotting] saved prediction: /home/rwhite/NFS/All_Team/Ryan/PEEK/runs/peek_detect/GSFC_satellite/frame00286.png
# [plotting] saved prediction: /home/rwhite/NFS/All_Team/Ryan/PEEK/runs/peek_detect/GSFC_satellite/frame00327.png
# [plotting] saved prediction: /home/rwhite/NFS/All_Team/Ryan/PEEK/runs/peek_detect/GSFC_satellite/frame01421.png
# [plotting] saved prediction: /home/rwhite/NFS/All_Team/Ryan/PEEK/runs/peek_detect/GSFC_satellite/frame01424.png
# [plotting] saved: /home/rwhite/NFS/All_Team/Ryan/PEEK/figures/GSFC_satellite/frame00000.png
# [plotting] saved: /home/rwhite/NFS/All_Team/Ryan/PEEK/figures/GSFC_satellite/frame00062.png
# [plotting] saved: /home/rwhite/NFS/All_Team/Ryan/PEEK/figures/GSFC_satellite/frame00099.png
# [plotting] saved: /home/rwhite/NFS/All_Team/Ryan/PEEK/figures/GSFC_satellite/frame00177.png
# [plotting] saved: /home/rwhite/NFS/All_Team/Ryan/PEEK/figures/GSFC_satellite/frame00286.png
# [plotting] saved: /home/rwhite/NFS/All_Team/Ryan/PEEK/figures/GSFC_satellite/frame00327.png
# [plotting] saved: /home/rwhite/NFS/All_Team/Ryan/PEEK/figures/GSFC_satellite/frame01421.png
# [plotting] saved: /home/rwhite/NFS/All_Team/Ryan/PEEK/figures/GSFC_satellite/frame01424.png
