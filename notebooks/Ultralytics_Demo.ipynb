# %% [markdown]
# # YOLO 26 Example

# %%
from peek.extractors.ultralytics import extract_ultralytics_latents

extract_ultralytics_latents(
    weights="weights/yolo26s.pt",
    image_dir="image_samples/imagenet_valset",
    out_dir="feature_maps/imagenet_valset_y26s",
    imgsz=640,
    modules=None,      # all modules by default
    verbose=True,
)

from peek import plot_PEEK

plot_PEEK(
    modules=[1, 7, 16, 19, 22],
    image_dir="image_samples/imagenet_valset",
    feature_folder="feature_maps/imagenet_valset_y26s",
    save_path="figures/imagenet_valset_y26s",
    run_path="auto",                           # generate predictions
    weights_path="weights/yolo26s.pt",                 # auto-download if missing
    imgsz=640,
    verbose=True,
)
# Out:
# [ultralytics] predict: ILSVRC2012_val_00000193.JPEG
# [ultralytics] predict: ILSVRC2012_val_00000195.JPEG
# [ultralytics] predict: ILSVRC2012_val_00000205.JPEG
# [ultralytics] predict: ILSVRC2012_val_00000206.JPEG
# [ultralytics] predict: ILSVRC2012_val_00000207.JPEG
# [ultralytics] predict: ILSVRC2012_val_00000208.JPEG
# [ultralytics] predict: ILSVRC2012_val_00000209.JPEG
# [ultralytics] predict: ILSVRC2012_val_00000210.JPEG
# [ultralytics] predict: ILSVRC2012_val_00000211.JPEG
# [ultralytics] predict: ILSVRC2012_val_00000212.JPEG
# [ultralytics] saved latents to: /home/rwhite/NFS/All_Team/Ryan/PEEK/feature_maps/imagenet_valset_y26s
# Results saved to /home/rwhite/NFS/All_Team/Ryan/PEEK/runs/peek_detect/imagenet_valset
# [plotting] saved predictions to: /home/rwhite/NFS/All_Team/Ryan/PEEK/runs/peek_detect/imagenet_valset
# [plotting] saved: /home/rwhite/NFS/All_Team/Ryan/PEEK/figures/imagenet_valset_y26s/ILSVRC2012_val_00000193.png
# [plotting] saved: /home/rwhite/NFS/All_Team/Ryan/PEEK/figures/imagenet_valset_y26s/ILSVRC2012_val_00000195.png
# [plotting] saved: /home/rwhite/NFS/All_Team/Ryan/PEEK/figures/imagenet_valset_y26s/ILSVRC2012_val_00000205.png
# [plotting] saved: /home/rwhite/NFS/All_Team/Ryan/PEEK/figures/imagenet_valset_y26s/ILSVRC2012_val_00000206.png
# [plotting] saved: /home/rwhite/NFS/All_Team/Ryan/PEEK/figures/imagenet_valset_y26s/ILSVRC2012_val_00000207.png
# [plotting] saved: /home/rwhite/NFS/All_Team/Ryan/PEEK/figures/imagenet_valset_y26s/ILSVRC2012_val_00000208.png
# [plotting] saved: /home/rwhite/NFS/All_Team/Ryan/PEEK/figures/imagenet_valset_y26s/ILSVRC2012_val_00000209.png
# [plotting] saved: /home/rwhite/NFS/All_Team/Ryan/PEEK/figures/imagenet_valset_y26s/ILSVRC2012_val_00000210.png
# [plotting] saved: /home/rwhite/NFS/All_Team/Ryan/PEEK/figures/imagenet_valset_y26s/ILSVRC2012_val_00000211.png
# [plotting] saved: /home/rwhite/NFS/All_Team/Ryan/PEEK/figures/imagenet_valset_y26s/ILSVRC2012_val_00000212.png

# %% [markdown]
# # YOLOv8 Example

# %%
from peek.extractors.ultralytics import extract_ultralytics_latents

extract_ultralytics_latents(
    weights="weights/yolov8s.pt",                 # or yolo8s.pt, yolo11s.pt, yolo26s.pt
    image_dir="image_samples/imagenet_valset",
    out_dir="feature_maps/imagenet_valset_y8s",
    device="0",
    imgsz=640,
    modules=None,                          # or select subset
    verbose=True,
)

from peek import plot_PEEK

plot_PEEK(
    modules=[1, 7, 16, 19, 22],
    image_dir="image_samples/imagenet_valset",
    feature_folder="feature_maps/imagenet_valset_y8s",
    save_path="figures/imagenet_valset_y8s",
    run_path="auto",                           # generate predictions
    weights_path="weights/yolov8s.pt",                 # auto-download if missing
    imgsz=640,
    verbose=True,    
)
# Out:
# [ultralytics] predict: ILSVRC2012_val_00000193.JPEG
# [ultralytics] predict: ILSVRC2012_val_00000195.JPEG
# [ultralytics] predict: ILSVRC2012_val_00000205.JPEG
# [ultralytics] predict: ILSVRC2012_val_00000206.JPEG
# [ultralytics] predict: ILSVRC2012_val_00000207.JPEG
# [ultralytics] predict: ILSVRC2012_val_00000208.JPEG
# [ultralytics] predict: ILSVRC2012_val_00000209.JPEG
# [ultralytics] predict: ILSVRC2012_val_00000210.JPEG
# [ultralytics] predict: ILSVRC2012_val_00000211.JPEG
# [ultralytics] predict: ILSVRC2012_val_00000212.JPEG
# [ultralytics] saved latents to: /home/rwhite/NFS/All_Team/Ryan/PEEK/feature_maps/imagenet_valset_y8s
# Results saved to /home/rwhite/NFS/All_Team/Ryan/PEEK/runs/peek_detect/imagenet_valset
# [plotting] saved predictions to: /home/rwhite/NFS/All_Team/Ryan/PEEK/runs/peek_detect/imagenet_valset
# [plotting] saved: /home/rwhite/NFS/All_Team/Ryan/PEEK/figures/imagenet_valset_y8s/ILSVRC2012_val_00000193.png
# [plotting] saved: /home/rwhite/NFS/All_Team/Ryan/PEEK/figures/imagenet_valset_y8s/ILSVRC2012_val_00000195.png
# [plotting] saved: /home/rwhite/NFS/All_Team/Ryan/PEEK/figures/imagenet_valset_y8s/ILSVRC2012_val_00000205.png
# [plotting] saved: /home/rwhite/NFS/All_Team/Ryan/PEEK/figures/imagenet_valset_y8s/ILSVRC2012_val_00000206.png
# [plotting] saved: /home/rwhite/NFS/All_Team/Ryan/PEEK/figures/imagenet_valset_y8s/ILSVRC2012_val_00000207.png
# [plotting] saved: /home/rwhite/NFS/All_Team/Ryan/PEEK/figures/imagenet_valset_y8s/ILSVRC2012_val_00000208.png
# [plotting] saved: /home/rwhite/NFS/All_Team/Ryan/PEEK/figures/imagenet_valset_y8s/ILSVRC2012_val_00000209.png
# [plotting] saved: /home/rwhite/NFS/All_Team/Ryan/PEEK/figures/imagenet_valset_y8s/ILSVRC2012_val_00000210.png
# [plotting] saved: /home/rwhite/NFS/All_Team/Ryan/PEEK/figures/imagenet_valset_y8s/ILSVRC2012_val_00000211.png
# [plotting] saved: /home/rwhite/NFS/All_Team/Ryan/PEEK/figures/imagenet_valset_y8s/ILSVRC2012_val_00000212.png

# %% [markdown]
# # YOLOv11 Example

# %%
from peek.extractors.ultralytics import extract_ultralytics_latents

extract_ultralytics_latents(
    weights="weights/yolo11s.pt",                 # or yolo8s.pt, yolo11s.pt, yolo26s.pt
    image_dir="image_samples/imagenet_valset",
    out_dir="feature_maps/imagenet_valset_y11s",
    device="0",
    imgsz=640,
    modules=None,                          # or select subset
    verbose=True,
)

from peek import plot_PEEK

plot_PEEK(
    modules=[1, 7, 16, 19, 22],
    image_dir="image_samples/imagenet_valset",
    feature_folder="feature_maps/imagenet_valset_y11s",
    save_path="figures/imagenet_valset_y11s",
    run_path="auto",                           # generate predictions
    weights_path="weights/yolo11s.pt",                 # auto-download if missing
    imgsz=640,
    verbose=True,    
)
# Out:
# [ultralytics] predict: ILSVRC2012_val_00000193.JPEG
# [ultralytics] predict: ILSVRC2012_val_00000195.JPEG
# [ultralytics] predict: ILSVRC2012_val_00000205.JPEG
# [ultralytics] predict: ILSVRC2012_val_00000206.JPEG
# [ultralytics] predict: ILSVRC2012_val_00000207.JPEG
# [ultralytics] predict: ILSVRC2012_val_00000208.JPEG
# [ultralytics] predict: ILSVRC2012_val_00000209.JPEG
# [ultralytics] predict: ILSVRC2012_val_00000210.JPEG
# [ultralytics] predict: ILSVRC2012_val_00000211.JPEG
# [ultralytics] predict: ILSVRC2012_val_00000212.JPEG
# [ultralytics] saved latents to: /home/rwhite/NFS/All_Team/Ryan/PEEK/feature_maps/imagenet_valset_y11s
# Results saved to /home/rwhite/NFS/All_Team/Ryan/PEEK/runs/peek_detect/imagenet_valset
# [plotting] saved predictions to: /home/rwhite/NFS/All_Team/Ryan/PEEK/runs/peek_detect/imagenet_valset
# [plotting] saved: /home/rwhite/NFS/All_Team/Ryan/PEEK/figures/imagenet_valset_y11s/ILSVRC2012_val_00000193.png
# [plotting] saved: /home/rwhite/NFS/All_Team/Ryan/PEEK/figures/imagenet_valset_y11s/ILSVRC2012_val_00000195.png
# [plotting] saved: /home/rwhite/NFS/All_Team/Ryan/PEEK/figures/imagenet_valset_y11s/ILSVRC2012_val_00000205.png
# [plotting] saved: /home/rwhite/NFS/All_Team/Ryan/PEEK/figures/imagenet_valset_y11s/ILSVRC2012_val_00000206.png
# [plotting] saved: /home/rwhite/NFS/All_Team/Ryan/PEEK/figures/imagenet_valset_y11s/ILSVRC2012_val_00000207.png
# [plotting] saved: /home/rwhite/NFS/All_Team/Ryan/PEEK/figures/imagenet_valset_y11s/ILSVRC2012_val_00000208.png
# [plotting] saved: /home/rwhite/NFS/All_Team/Ryan/PEEK/figures/imagenet_valset_y11s/ILSVRC2012_val_00000209.png
# [plotting] saved: /home/rwhite/NFS/All_Team/Ryan/PEEK/figures/imagenet_valset_y11s/ILSVRC2012_val_00000210.png
# [plotting] saved: /home/rwhite/NFS/All_Team/Ryan/PEEK/figures/imagenet_valset_y11s/ILSVRC2012_val_00000211.png
# [plotting] saved: /home/rwhite/NFS/All_Team/Ryan/PEEK/figures/imagenet_valset_y11s/ILSVRC2012_val_00000212.png
